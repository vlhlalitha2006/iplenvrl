# %% [markdown]
# # 🏏 IPL RL Environment - Hackathon Demo
#
# Multi-agent reinforcement learning for IPL auction strategy

# %%
import os, sys
REPO = "/content/iplenvrl"

if os.path.exists(REPO):
    # !rm -rf {REPO}

# !git clone https://github.com/vlhlalitha2006/iplenvrl.git {REPO}
os.chdir(REPO)

if REPO not in sys.path:
    sys.path.insert(0, REPO)

print("Repo ready:", os.getcwd())
# Out:
# Cloning into '/content/iplenvrl'...
# remote: Enumerating objects: 62, done.
# remote: Counting objects: 100% (62/62), done.
# remote: Compressing objects: 100% (60/60), done.
# remote: Total 62 (delta 0), reused 62 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (62/62), 837.90 KiB | 2.47 MiB/s, done.
# Repo ready: /content/iplenvrl

# %%
# !pip -q install -r requirements.txt

# %%
# Patch train.py in-place to force no-PPO mode (Colab-safe)
import re

p = "/content/iplenvrl/training/train.py"
txt = open(p, "r", encoding="utf-8").read()

# 1) force PPO availability flag off
txt = txt.replace("TRL_PPO_AVAILABLE = True", "TRL_PPO_AVAILABLE = False")

# 2) if that line doesn't exist in your version, make a safe override after imports
if "TRL_PPO_AVAILABLE = False" not in txt:
    txt = re.sub(
        r"(from transformers import AutoModelForCausalLM, AutoTokenizer\s*\n)",
        r"\1TRL_PPO_AVAILABLE = False\n",
        txt,
        count=1,
    )

open(p, "w", encoding="utf-8").write(txt)
print("Patched train.py: PPO disabled for Colab.")
# Out:
# Patched train.py: PPO disabled for Colab.

# %%
# !pkill -f "python app.py" || true

import importlib, app
importlib.reload(app)

app_obj, local_url, share_url = app.demo.launch(
    share=True,
    server_name="0.0.0.0",
    prevent_thread_lock=True
)

print("Local URL :", local_url)
print("Public URL:", share_url)
# Out:
# ^C
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://57044ab568504a860d.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://57044ab568504a860d.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Local URL : http://localhost:7861/
# Public URL: https://57044ab568504a860d.gradio.live

# %%
import os, sys, importlib
os.chdir("/content/iplenvrl")
if "/content/iplenvrl" not in sys.path:
    sys.path.insert(0, "/content/iplenvrl")

# %%
# !pkill -f "python app.py" || true

import app
importlib.reload(app)

app_obj, local_url, share_url = app.demo.launch(
    share=True,
    server_name="0.0.0.0",
    prevent_thread_lock=True
)

print("Public URL:", share_url)
# Out:
# ^C
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://7bc2dd63bcb7e6abb8.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://7bc2dd63bcb7e6abb8.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Public URL: https://7bc2dd63bcb7e6abb8.gradio.live

# %%
import os, sys
REPO = "/content/iplenvrl"

if os.path.exists(REPO):
    # !git -C {REPO} pull
else:
    # !git clone https://github.com/vlhlalitha2006/iplenvrl.git {REPO}

os.chdir(REPO)
if REPO not in sys.path:
    sys.path.insert(0, REPO)

print("Using repo:", os.getcwd())
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 1.61 KiB | 411.00 KiB/s, done.
# From https://github.com/vlhlalitha2006/iplenvrl
#    2ff6796..1603075  main       -> origin/main
# Updating 2ff6796..1603075
# Fast-forward
#  app.py | 105 ++++++++++++++++++++++++++++++++++++++++++++++++++++++-----------
#  1 file changed, 88 insertions(+), 17 deletions(-)
# Using repo: /content/iplenvrl

# %%
# !pkill -f "python app.py" || true
# Out:
# ^C

# %%
import importlib, app
importlib.reload(app)

app_obj, local_url, share_url = app.demo.launch(
    share=True,
    server_name="0.0.0.0",
    prevent_thread_lock=True
)

print("Public URL:", share_url)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://78afbab893cc535270.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://78afbab893cc535270.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Public URL: https://78afbab893cc535270.gradio.live

# %%
# !git -C /content/iplenvrl pull
# !pkill -f "python app.py" || true
# Out:
# Already up to date.
# ^C

# %%
import os, sys, importlib
os.chdir("/content/iplenvrl")
if "/content/iplenvrl" not in sys.path:
    sys.path.insert(0, "/content/iplenvrl")

import app
importlib.reload(app)

app_obj, local_url, share_url = app.demo.launch(
    share=True,
    server_name="0.0.0.0",
    prevent_thread_lock=True
)

print("Public URL:", share_url)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://d89dde5ef2f2052f5e.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://d89dde5ef2f2052f5e.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Public URL: https://d89dde5ef2f2052f5e.gradio.live

# %%
# !git -C /content/iplenvrl pull
# !pkill -f "python app.py" || true
# Out:
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 4), reused 4 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (6/6), 1.35 KiB | 344.00 KiB/s, done.
# From https://github.com/vlhlalitha2006/iplenvrl
#    1603075..5494f5b  main       -> origin/main
# Updating 1603075..5494f5b
# Fast-forward
#  app.py | 32 ++++++++++++++++++++++++++++++--
#  1 file changed, 30 insertions(+), 2 deletions(-)
# ^C

# %%
import os, sys, importlib
os.chdir("/content/iplenvrl")
if "/content/iplenvrl" not in sys.path:
    sys.path.insert(0, "/content/iplenvrl")

import app
importlib.reload(app)

app_obj, local_url, share_url = app.demo.launch(
    share=True,
    server_name="0.0.0.0",
    prevent_thread_lock=True
)
print("Public URL:", share_url)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://63d6e679e4875132b3.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://63d6e679e4875132b3.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Public URL: https://63d6e679e4875132b3.gradio.live

# %%
# !git -C /content/iplenvrl pull
# !pkill -f "python app.py" || true
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 1.69 KiB | 864.00 KiB/s, done.
# From https://github.com/vlhlalitha2006/iplenvrl
#    5494f5b..2d35605  main       -> origin/main
# Updating 5494f5b..2d35605
# Fast-forward
#  app.py | 98 ++++++++++++++++++++++++++++++++++++++++++++++++++++--------------
#  1 file changed, 78 insertions(+), 20 deletions(-)
# ^C

# %%
import os, sys, importlib
os.chdir("/content/iplenvrl")
if "/content/iplenvrl" not in sys.path:
    sys.path.insert(0, "/content/iplenvrl")

import app
importlib.reload(app)

app_obj, local_url, share_url = app.demo.launch(
    share=True,
    server_name="0.0.0.0",
    prevent_thread_lock=True
)
print("Public URL:", share_url)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://77025a68ef66c2e316.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://77025a68ef66c2e316.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Public URL: https://77025a68ef66c2e316.gradio.live

# %%
# !git -C /content/iplenvrl pull
# !pkill -f "python app.py" || true
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 1.30 KiB | 665.00 KiB/s, done.
# From https://github.com/vlhlalitha2006/iplenvrl
#    2d35605..0de94aa  main       -> origin/main
# Updating 2d35605..0de94aa
# Fast-forward
#  app.py | 122 ++++++++++++++++++++++++++++++++++++++++-------------------------
#  1 file changed, 76 insertions(+), 46 deletions(-)
# ^C

# %%
import os, sys, importlib
os.chdir("/content/iplenvrl")
if "/content/iplenvrl" not in sys.path:
    sys.path.insert(0, "/content/iplenvrl")

import app
importlib.reload(app)

app_obj, local_url, share_url = app.demo.launch(
    share=True,
    server_name="0.0.0.0",
    prevent_thread_lock=True
)
print("Public URL:", share_url)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_12544/1838431551.py in <cell line: 0>()
#       1 import os, sys, importlib
# ----> 2 os.chdir("/content/iplenvrl")
#       3 if "/content/iplenvrl" not in sys.path:
#       4     sys.path.insert(0, "/content/iplenvrl")
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/iplenvrl'

# %%
import os, sys, importlib

candidates = ["/content/iplenvrl", "/content/IPL-RL-ENV"]
repo = next((p for p in candidates if os.path.exists(p)), None)

if repo is None:
    raise FileNotFoundError("Repo not found. Clone first with: !git clone https://github.com/vlhlalitha2006/iplenvrl.git /content/iplenvrl")

os.chdir(repo)
if repo not in sys.path:
    sys.path.insert(0, repo)

import app
importlib.reload(app)

app_obj, local_url, share_url = app.demo.launch(
    share=True,
    server_name="0.0.0.0",
    prevent_thread_lock=True
)

print("Using repo:", repo)
print("Public URL:", share_url)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_12544/1590066000.py in <cell line: 0>()
#       5
#       6 if repo is None:
# ----> 7     raise FileNotFoundError("Repo not found. Clone first with: !git clone https://github.com/vlhlalitha2006/iplenvrl.git /content/iplenvrl")
#       8
#       9 os.chdir(repo)
#
# FileNotFoundError: Repo not found. Clone first with: !git clone https://github.com/vlhlalitha2006/iplenvrl.git /content/iplenvrl

# %%
# !ls /content
# Out:
# sample_data

# %%
# !git clone https://github.com/vlhlalitha2006/iplenvrl.git /content/iplenvrl
# Out:
# Cloning into '/content/iplenvrl'...
# remote: Enumerating objects: 80, done.
# remote: Counting objects: 100% (80/80), done.
# remote: Compressing objects: 100% (71/71), done.
# remote: Total 80 (delta 12), reused 75 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (80/80), 848.61 KiB | 5.30 MiB/s, done.
# Resolving deltas: 100% (12/12), done.

# %%
import os, sys, importlib

os.chdir("/content/iplenvrl")   # correct path
if "/content/iplenvrl" not in sys.path:
    sys.path.insert(0, "/content/iplenvrl")

import app
importlib.reload(app)

app_obj, local_url, share_url = app.demo.launch(
    share=True,
    server_name="0.0.0.0",
    prevent_thread_lock=True
)

print("Public URL:", share_url)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://35e07680382547140d.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://35e07680382547140d.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Public URL: https://35e07680382547140d.gradio.live
